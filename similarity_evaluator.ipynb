# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import zipfile
import json
import pandas as pd
os.chdir('/content/drive/MyDrive/AI_in_Data_Science/projekt_munka_viragok')
from classok import EmbeddingPlotter, EmbeddingSimilarityEvaluator, EmbeddingClassifier

# %%
# Define the extracted folder path
dataset_path = "/content/drive/MyDrive/AI_in_Data_Science/projekt_munka_viragok/archive (2).zip"
extract_path = "/content/"

if os.path.exists(dataset_path):
    with zipfile.ZipFile(dataset_path, "r") as zip_ref:
        zip_ref.extractall(extract_path)
    print("Dataset extracted successfully.")
else:
    print("Zip file not found.")

# Load label mappings
with open("/content/cat_to_name.json", "r") as f:
    label_map = json.load(f)

# Define base directory and splits
base_dir = "/content/dataset"
splits = ["train", "valid"]
# Out:
# Dataset extracted successfully.

# %%
plotter = EmbeddingPlotter("/content/drive/MyDrive/AI_in_Data_Science/projekt_munka_viragok/flower_embeddings_with_label_without_name.json")

plotter.plot(method="tsne", use="combined")
plotter.plot(method="tsne", use="text")
plotter.plot(method="tsne", use="image")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %%
plotter = EmbeddingPlotter("/content/drive/MyDrive/AI_in_Data_Science/projekt_munka_viragok/flower_embeddings_without_label.json")

plotter.plot(method="tsne", use="combined")
plotter.plot(method="tsne", use="text")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %%
plotter = EmbeddingPlotter("/content/drive/MyDrive/AI_in_Data_Science/projekt_munka_viragok/flower_embeddings_with_label.json")

plotter.plot(method="tsne", use="combined")
plotter.plot(method="tsne", use="text")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %%
# Text Embedding Classification using Logistic Regression
text_classifier_with_label = EmbeddingClassifier(
    json_path='/content/drive/MyDrive/AI_in_Data_Science/projekt_munka_viragok/flower_embeddings_with_label.json',
    embedding_type='text embedding',
    model_type='logistic'
)
text_classifier_with_label.run()

text_classifier_without_label = EmbeddingClassifier(
    json_path='/content/drive/MyDrive/AI_in_Data_Science/projekt_munka_viragok/flower_embeddings_without_label.json',
    embedding_type='text embedding',
    model_type='logistic'
)
text_classifier_without_label.run()

text_classifier_with_label_without_name = EmbeddingClassifier(
    json_path='/content/drive/MyDrive/AI_in_Data_Science/projekt_munka_viragok/flower_embeddings_with_label_without_name.json',
    embedding_type='text embedding',
    model_type='logistic'
)
text_classifier_with_label_without_name.run()

# Image Embedding Classification using Random Forest
image_classifier = EmbeddingClassifier(
    json_path='/content/drive/MyDrive/AI_in_Data_Science/projekt_munka_viragok/flower_embeddings_with_label.json',
    embedding_type='image embedding',
    model_type='logistic'
)
image_classifier.run()
# Out:
# --- Kiértékelési jelentés text embedding használatával logistic modell esetén ---
#                            precision    recall  f1-score   support
#
#          alpine sea holly       1.00      1.00      1.00         3
#                 artichoke       1.00      1.00      1.00         6
#            balloon flower       1.00      1.00      1.00         4
#            barbeton daisy       0.56      0.50      0.53        10
#          bird of paradise       0.50      0.57      0.53         7
#          bolero deep blue       1.00      0.67      0.80         3
#                 buttercup       0.40      0.33      0.36         6
#          canterbury bells       1.00      1.00      1.00         4
#               cape flower       1.00      1.00      1.00         9
#                 carnation       1.00      0.80      0.89         5
#               colt's foot       1.00      1.00      1.00         7
#          common dandelion       0.56      0.71      0.62         7
#                corn poppy       1.00      1.00      1.00         3
#                  daffodil       0.40      0.40      0.40         5
#          english marigold       1.00      1.00      1.00         5
#                 fire lily       1.00      0.67      0.80         3
#                fritillary       1.00      1.00      1.00         7
#              garden phlox       1.00      1.00      1.00         4
#     giant white arum lily       1.00      1.00      1.00         5
#             globe thistle       0.50      0.50      0.50         4
#              globe-flower       1.00      1.00      1.00         4
#            grape hyacinth       1.00      0.67      0.80         3
#          great masterwort       1.00      1.00      1.00         4
# hard-leaved pocket orchid       1.00      1.00      1.00         4
#               king protea       1.00      1.00      1.00         4
#               lenten rose       1.00      1.00      1.00         5
#          love in the mist       1.00      1.00      1.00         3
#                  marigold       0.57      0.67      0.62         6
#             mexican aster       1.00      1.00      1.00         3
#                 monkshood       0.75      0.75      0.75         4
#               moon orchid       0.00      0.00      0.00         3
#               oxeye daisy       1.00      0.50      0.67         4
#             peruvian lily       1.00      1.00      1.00         7
#                   petunia       0.60      0.71      0.65        21
#         pincushion flower       1.00      0.80      0.89         5
#             pink primrose       1.00      1.00      1.00         3
#                poinsettia       0.64      1.00      0.78         7
#  prince of wales feathers       1.00      1.00      1.00         4
#         purple coneflower       1.00      1.00      1.00         6
#                red ginger       1.00      1.00      1.00         4
#      ruby-lipped cattleya       1.00      1.00      1.00         6
#                siam tulip       1.00      1.00      1.00         3
#                snapdragon       1.00      0.86      0.92         7
#             spear thistle       1.00      1.00      1.00         4
#          stemless gentian       1.00      1.00      1.00         6
#                 sweet pea       1.00      1.00      1.00         4
#             sweet william       0.67      1.00      0.80         6
#                sword lily       0.50      0.30      0.38        10
#                tiger lily       1.00      1.00      1.00         4
#                wallflower       0.62      0.62      0.62        16
#               yellow iris       1.00      1.00      1.00         4
#
#                  accuracy                           0.81       281
#                 macro avg       0.87      0.84      0.85       281
#              weighted avg       0.82      0.81      0.81       281
#
#
# --- Kiértékelési jelentés text embedding használatával logistic modell esetén ---
#                            precision    recall  f1-score   support
#
#          alpine sea holly       0.00      0.00      0.00         3
#                 artichoke       0.00      0.00      0.00         6
#            balloon flower       0.00      0.00      0.00         4
#            barbeton daisy       0.12      0.10      0.11        10
#          bird of paradise       0.50      0.29      0.36         7
#          bolero deep blue       0.00      0.00      0.00         3
#                 buttercup       0.00      0.00      0.00         6
#          canterbury bells       0.00      0.00      0.00         1
#               cape flower       0.27      0.33      0.30         9
#                 carnation       0.33      0.20      0.25         5
#               colt's foot       0.25      0.43      0.32         7
#          common dandelion       0.50      0.43      0.46         7
#                corn poppy       0.67      0.67      0.67         3
#                  daffodil       0.33      0.20      0.25         5
#          english marigold       0.14      0.20      0.17         5
#                 fire lily       0.00      0.00      0.00         3
#                fritillary       0.14      0.14      0.14         7
#              garden phlox       0.25      0.25      0.25         4
#     giant white arum lily       0.20      0.20      0.20         5
#             globe thistle       0.00      0.00      0.00         4
#              globe-flower       0.20      0.25      0.22         4
#            grape hyacinth       0.00      0.00      0.00         3
#          great masterwort       0.00      0.00      0.00         4
# hard-leaved pocket orchid       0.33      0.20      0.25         5
#               king protea       0.50      0.25      0.33         4
#               lenten rose       0.00      0.00      0.00         5
#          love in the mist       0.50      0.33      0.40         3
#                  marigold       0.33      0.50      0.40         6
#             mexican aster       0.00      0.00      0.00         3
#                 monkshood       0.14      0.25      0.18         4
#               moon orchid       1.00      0.67      0.80         3
#               oxeye daisy       0.33      0.50      0.40         4
#             peruvian lily       0.33      0.14      0.20         7
#                   petunia       0.25      0.38      0.30        21
#         pincushion flower       0.00      0.00      0.00         5
#             pink primrose       0.25      0.33      0.29         3
#                poinsettia       0.18      0.43      0.25         7
#  prince of wales feathers       0.00      0.00      0.00         4
#         purple coneflower       0.43      0.50      0.46         6
#                red ginger       0.33      0.25      0.29         4
#      ruby-lipped cattleya       0.33      0.17      0.22         6
#                siam tulip       0.33      0.33      0.33         3
#                snapdragon       0.17      0.14      0.15         7
#             spear thistle       0.33      0.25      0.29         4
#          stemless gentian       0.56      0.83      0.67         6
#                 sweet pea       0.00      0.00      0.00         4
#             sweet william       0.00      0.00      0.00         6
#                sword lily       0.17      0.10      0.12        10
#                tiger lily       1.00      0.50      0.67         4
#                wallflower       0.24      0.42      0.30        12
#               yellow iris       0.33      0.50      0.40         4
#
#                  accuracy                           0.25       275
#                 macro avg       0.24      0.23      0.22       275
#              weighted avg       0.24      0.25      0.23       275
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# --- Kiértékelési jelentés text embedding használatával logistic modell esetén ---
#                            precision    recall  f1-score   support
#
#          alpine sea holly       0.00      0.00      0.00         3
#                 artichoke       0.22      0.33      0.27         6
#            balloon flower       0.00      0.00      0.00         4
#            barbeton daisy       0.20      0.20      0.20        10
#          bird of paradise       0.50      0.43      0.46         7
#          bolero deep blue       1.00      0.33      0.50         3
#                 buttercup       0.25      0.17      0.20         6
#          canterbury bells       1.00      0.75      0.86         4
#               cape flower       0.23      0.33      0.27         9
#                 carnation       0.00      0.00      0.00         5
#               colt's foot       0.50      0.71      0.59         7
#          common dandelion       0.40      0.57      0.47         7
#                corn poppy       0.50      0.67      0.57         3
#                  daffodil       0.33      0.40      0.36         5
#          english marigold       0.60      0.60      0.60         5
#                 fire lily       0.00      0.00      0.00         3
#                fritillary       0.38      0.43      0.40         7
#              garden phlox       0.00      0.00      0.00         4
#     giant white arum lily       0.30      0.60      0.40         5
#             globe thistle       0.00      0.00      0.00         4
#              globe-flower       1.00      0.50      0.67         4
#            grape hyacinth       0.00      0.00      0.00         3
#          great masterwort       0.00      0.00      0.00         4
# hard-leaved pocket orchid       1.00      0.25      0.40         4
#               king protea       0.50      0.25      0.33         4
#               lenten rose       0.12      0.20      0.15         5
#          love in the mist       0.00      0.00      0.00         3
#                  marigold       0.00      0.00      0.00         6
#             mexican aster       0.50      0.67      0.57         3
#                 monkshood       0.33      0.50      0.40         4
#               moon orchid       0.00      0.00      0.00         3
#               oxeye daisy       1.00      0.25      0.40         4
#             peruvian lily       0.45      0.71      0.56         7
#                   petunia       0.38      0.38      0.38        21
#         pincushion flower       0.00      0.00      0.00         5
#             pink primrose       0.00      0.00      0.00         3
#                poinsettia       0.67      0.86      0.75         7
#  prince of wales feathers       0.33      0.25      0.29         4
#         purple coneflower       0.18      0.33      0.24         6
#                red ginger       0.33      0.50      0.40         4
#      ruby-lipped cattleya       0.67      0.67      0.67         6
#                siam tulip       0.00      0.00      0.00         3
#                snapdragon       0.38      0.43      0.40         7
#             spear thistle       0.60      0.75      0.67         4
#          stemless gentian       0.60      0.50      0.55         6
#                 sweet pea       0.00      0.00      0.00         4
#             sweet william       0.33      0.33      0.33         6
#                sword lily       0.40      0.20      0.27        10
#                tiger lily       0.50      0.25      0.33         4
#                wallflower       0.32      0.44      0.37        16
#               yellow iris       0.00      0.00      0.00         4
#
#                  accuracy                           0.34       281
#                 macro avg       0.33      0.31      0.30       281
#              weighted avg       0.34      0.34      0.33       281
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# --- Kiértékelési jelentés image embedding használatával logistic modell esetén ---
#                            precision    recall  f1-score   support
#
#          alpine sea holly       1.00      1.00      1.00         3
#                 artichoke       1.00      1.00      1.00         6
#            balloon flower       1.00      1.00      1.00         4
#            barbeton daisy       1.00      1.00      1.00        10
#          bird of paradise       1.00      1.00      1.00         7
#          bolero deep blue       1.00      1.00      1.00         3
#                 buttercup       1.00      1.00      1.00         6
#          canterbury bells       1.00      1.00      1.00         4
#               cape flower       1.00      1.00      1.00         9
#                 carnation       1.00      1.00      1.00         5
#               colt's foot       1.00      1.00      1.00         7
#          common dandelion       1.00      1.00      1.00         7
#                corn poppy       1.00      1.00      1.00         3
#                  daffodil       1.00      1.00      1.00         5
#          english marigold       1.00      1.00      1.00         5
#                 fire lily       1.00      1.00      1.00         3
#                fritillary       1.00      1.00      1.00         7
#              garden phlox       1.00      1.00      1.00         4
#     giant white arum lily       1.00      1.00      1.00         5
#             globe thistle       1.00      1.00      1.00         4
#              globe-flower       1.00      1.00      1.00         4
#            grape hyacinth       1.00      1.00      1.00         3
#          great masterwort       1.00      1.00      1.00         4
# hard-leaved pocket orchid       1.00      1.00      1.00         4
#               king protea       1.00      1.00      1.00         4
#               lenten rose       1.00      1.00      1.00         5
#          love in the mist       1.00      1.00      1.00         3
#                  marigold       1.00      1.00      1.00         6
#             mexican aster       1.00      1.00      1.00         3
#                 monkshood       1.00      1.00      1.00         4
#               moon orchid       1.00      1.00      1.00         3
#               oxeye daisy       1.00      1.00      1.00         4
#             peruvian lily       1.00      1.00      1.00         7
#                   petunia       1.00      1.00      1.00        21
#         pincushion flower       1.00      1.00      1.00         5
#             pink primrose       1.00      1.00      1.00         3
#                poinsettia       1.00      1.00      1.00         7
#  prince of wales feathers       1.00      1.00      1.00         4
#         purple coneflower       1.00      1.00      1.00         6
#                red ginger       1.00      1.00      1.00         4
#      ruby-lipped cattleya       1.00      1.00      1.00         6
#                siam tulip       1.00      1.00      1.00         3
#                snapdragon       1.00      1.00      1.00         7
#             spear thistle       1.00      1.00      1.00         4
#          stemless gentian       1.00      1.00      1.00         6
#                 sweet pea       1.00      1.00      1.00         4
#             sweet william       1.00      1.00      1.00         6
#                sword lily       1.00      1.00      1.00        10
#                tiger lily       1.00      1.00      1.00         4
#                wallflower       1.00      1.00      1.00        16
#               yellow iris       1.00      1.00      1.00         4
#
#                  accuracy                           1.00       281
#                 macro avg       1.00      1.00      1.00       281
#              weighted avg       1.00      1.00      1.00       281

# %%
evaluator = EmbeddingSimilarityEvaluator('/content/drive/MyDrive/AI_in_Data_Science/projekt_munka_viragok/flower_embeddings_with_label.json')

evaluator.run_retrieval_evaluation(
    k=1,
    num_examples=15,
    #labels_to_show=["pink primrose"],
    show_correct=True,           # show incorrect retrievals
    use_csls=False         # ✅ important
)

# %%
paths = [
    "/content/drive/MyDrive/AI_in_Data_Science/projekt_munka_viragok/flower_embeddings_without_label.json",
    "/content/drive/MyDrive/AI_in_Data_Science/projekt_munka_viragok/flower_embeddings_with_label.json",
    "/content/drive/MyDrive/AI_in_Data_Science/projekt_munka_viragok/flower_embeddings_with_label_without_name.json"
]

results = []
for path in paths:
    evaluator = EmbeddingSimilarityEvaluator(path)
    evaluator.load_embeddings()
    results.append(evaluator.evaluate_all(k=5))

df_results = pd.DataFrame(results)
csv_path = "/content/drive/MyDrive/AI_in_Data_Science/projekt_munka_viragok/similarity_evaluation_results.csv"
df_results.to_csv(csv_path, index=False)
